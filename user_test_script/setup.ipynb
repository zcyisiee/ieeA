# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://127.0.0.1:8045/v1",
    api_key="sk-174d582f879f42e297a08aad2f9d7547"
)

response = client.chat.completions.create(
    model="claude-opus-4-6-thinking",
    messages=[{"role": "user", "content": "Hello"}]
)

print(response.choices[0].message.content)
# Out:
# Hello! I'm Antigravity, your AI coding assistant. How can I help you today? Whether you need to:
#
# - **Build** something new from scratch
# - **Debug** an existing issue
# - **Modify** or refactor code
# - **Answer** a technical question
# - **Review** code or architecture
#
# Just let me know what you're working on, and we'll tackle it together! 🚀

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://127.0.0.1:8045/v1",
    api_key="sk-174d582f879f42e297a08aad2f9d7547"
)

response = client.chat.completions.create(
    model="claude-opus-4-6-thinking",
    messages=[{"role": "user", "content": "Hello"}]
)

print(response.choices[0].message.content)
# Out:
# Hello! I'm Antigravity, your AI coding assistant. How can I help you today? Whether you need to:
#
# - **Build** something new
# - **Debug** an existing issue
# - **Modify** or refactor code
# - **Answer** a technical question
#
# I'm ready to dive in. What are you working on?

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://127.0.0.1:8045/v1",
    api_key="sk-174d582f879f42e297a08aad2f9d7547"
)

response = client.chat.completions.create(
    model="claude-sonnet-4-5",
    messages=[{"role": "user", "content": "Hello"}]
)

print(response.choices[0].message.content)
# Out:
# Hello! I'm Antigravity, your AI coding assistant. I'm here to help you with any coding tasks you have in mind.
#
# Whether you need to:
# - Create a new project or codebase from scratch
# - Debug or modify existing code
# - Discuss architecture and design decisions
# - Answer technical questions
# - Review and optimize code
#
# I'm ready to assist! What would you like to work on today?

# %% [markdown]
# ## 测试中转站

# %%
from openai import OpenAI

client = OpenAI(
    base_url="https://jeniya.top/v1",
    api_key="sk-6etQJpowIlOQNlVEfaIktm21lcTdgyUQIODIuMz3QDIQTCU0"
)

response = client.chat.completions.create(
    model="gemini-3-pro-preview",
    messages=[{"role": "user", "content": "Hello, 请用中文回复"}],
    temperature=0.3,
    max_tokens=10000
)

print("连接成功！")
print(f"模型响应: {response.choices[0].message.content}")
print(f"使用模型: {response.model}")
print(f"Token 用量: {response.usage}")
# Out:
# 连接成功！
# 模型响应: 您好！没问题，我会用中文回复。请问有什么我可以帮您的吗？
# 使用模型: gemini-3-pro-preview
# Token 用量: CompletionUsage(completion_tokens=397, prompt_tokens=7, total_tokens=404, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=378, rejected_prediction_tokens=None, text_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0, text_tokens=7, image_tokens=0), input_tokens=0, output_tokens=0, input_tokens_details=None, claude_cache_creation_5_m_tokens=0, claude_cache_creation_1_h_tokens=0)
